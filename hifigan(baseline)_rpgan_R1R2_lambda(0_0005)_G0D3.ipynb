# %% [markdown]
# <a href="https://colab.research.google.com/github/kimdonggyu2008/deep_daiv_-/blob/main/hifigan(baseline)_rpgan_R1R2_lambda(0_0005)_G0D3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive, output
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install wavenet_vocoder
# !pip install librosa==0.9.1
# !pip install wandb
# !pip install "pip<24.1"
# !pip install git+https://github.com/One-sixth/fairseq.git
output.clear()

# %%
# %cd /content/drive/MyDrive/코딩공부/deep_daiv/PAPER_SUBMIT
# 본인 폴더 경로로 변경
# Out:
# /content/drive/MyDrive/코딩공부/deep_daiv/PAPER_SUBMIT

# %%
# !pip install torchinfo
# !pip install --upgrade scoreq
# !pip install torch-pesq
# !pip install praat-parselmouth
output.clear()

# %%
import os
import pickle
import numpy as np
import soundfile as sf
from scipy import signal
from scipy.signal import get_window
from librosa.filters import mel
from numpy.random import RandomState
import torch
import torch.nn as nn
from collections import OrderedDict
import torch.nn.functional as F
from torch.utils import data
from multiprocessing import Process, Manager
import easydict
from torch.backends import cudnn
import time
import datetime
from math import ceil
from tqdm import tqdm
from wavenet_vocoder import builder
from torch_pesq import PesqLoss
import scoreq
from torchinfo import summary
output.clear()

# %%
#utils
import glob
import os
import matplotlib
import torch
from torch.nn.utils import weight_norm
matplotlib.use("Agg")
import matplotlib.pylab as plt


def plot_spectrogram(spectrogram):
    fig, ax = plt.subplots(figsize=(10, 2))
    im = ax.imshow(spectrogram, aspect="auto", origin="lower",
                   interpolation='none')
    plt.colorbar(im, ax=ax)

    fig.canvas.draw()
    plt.close()

    return fig


def init_weights(m, mean=0.0, std=0.01):
    classname = m.__class__.__name__
    if classname.find("Conv") != -1:
        m.weight.data.normal_(mean, std)


def apply_weight_norm(m):
    classname = m.__class__.__name__
    if classname.find("Conv") != -1:
        weight_norm(m)


def get_padding(kernel_size, dilation=1):
    return int((kernel_size*dilation - dilation)/2)


def load_checkpoint(filepath, device):
    assert os.path.isfile(filepath)
    print("Loading '{}'".format(filepath))
    checkpoint_dict = torch.load(filepath, map_location=device)
    print("Complete.")
    return checkpoint_dict


def save_checkpoint(filepath, obj):
    print("Saving checkpoint to {}".format(filepath))
    torch.save(obj, filepath)
    print("Complete.")


def scan_checkpoint(cp_dir, prefix):
    pattern = os.path.join(cp_dir, prefix + '????????')
    cp_list = glob.glob(pattern)
    if len(cp_list) == 0:
        return None
    return sorted(cp_list)[-1]

# %%
#env
import os
import shutil

class AttrDict(dict):
    def __init__(self, *args, **kwargs):
        super(AttrDict, self).__init__(*args, **kwargs)
        self.__dict__ = self


def build_env(config, config_name, path): # env_path : cp_hifigan/config_v1.json에 저장
    t_path = os.path.join(path, config_name)
    if config != t_path:
        os.makedirs(path, exist_ok=True)
        shutil.copyfile(config, os.path.join(path, config_name))

# %%
import math
import os
import random
import torch
import torch.utils.data
import numpy as np
from librosa.util import normalize
from scipy.io.wavfile import read
from librosa.filters import mel as librosa_mel_fn

MAX_WAV_VALUE = 32768.0

def load_wav(full_path):
    sampling_rate, data = read(full_path)
    return data, sampling_rate

def dynamic_range_compression(x, C=1, clip_val=1e-5):
    return np.log(np.clip(x, a_min=clip_val, a_max=None) * C)

def dynamic_range_decompression(x, C=1):
    return np.exp(x) / C

def dynamic_range_compression_torch(x, C=1, clip_val=1e-5):
    return torch.log(torch.clamp(x, min=clip_val) * C)

def dynamic_range_decompression_torch(x, C=1):
    return torch.exp(x) / C

def spectral_normalize_torch(magnitudes):
    output = dynamic_range_compression_torch(magnitudes)
    return output

def spectral_de_normalize_torch(magnitudes):
    output = dynamic_range_decompression_torch(magnitudes)
    return output

mel_basis = {}
hann_window = {}

def mel_spectrogram(y, n_fft, num_mels, sampling_rate, hop_size, win_size, fmin, fmax, center=False):
    if torch.min(y) < -1.:
        print('min value is ', torch.min(y))
    if torch.max(y) > 1.:
        print('max value is ', torch.max(y))

    global mel_basis, hann_window
    if fmax not in mel_basis:
        mel = librosa_mel_fn(sampling_rate, n_fft, num_mels, fmin, fmax)
        mel_basis[str(fmax)+'_'+str(y.device)] = torch.from_numpy(mel).float().to(y.device)
        hann_window[str(y.device)] = torch.hann_window(win_size).to(y.device)

    # Apply padding and calculate STFT
    y = torch.nn.functional.pad(y.unsqueeze(1), (int((n_fft-hop_size)/2), int((n_fft-hop_size)/2)), mode='reflect')
    y = y.squeeze(1)

    spec = torch.stft(y, n_fft, hop_length=hop_size, win_length=win_size, window=hann_window[str(y.device)],
                      center=center, pad_mode='reflect', normalized=False, onesided=True, return_complex=True)

    # STFT의 결과에서 절대값을 취해 크기만 남김
    spec = spec.abs()

    # spec의 차원이 (n_frames, frequency_bins) 형식으로 맞는지 확인
    if len(spec.shape) == 3:
        spec = spec.squeeze(1)

    # mel_basis와 spec의 차원이 맞는지 확인한 후 matmul 실행
    spec = torch.matmul(mel_basis[str(fmax)+'_'+str(y.device)], spec)
    spec = spectral_normalize_torch(spec)

    return spec

def get_dataset_filelist(a):
    with open(a.input_training_file, 'r', encoding='utf-8') as fi:
        training_files = [os.path.join(a.input_wavs_dir, x.split('|')[0] + '.wav')
                          for x in fi.read().split('\n') if len(x) > 0]

    with open(a.input_validation_file, 'r', encoding='utf-8') as fi:
        validation_files = [os.path.join(a.input_wavs_dir, x.split('|')[0] + '.wav')
                            for x in fi.read().split('\n') if len(x) > 0]
    return training_files, validation_files

class MelDataset(torch.utils.data.Dataset):
    def __init__(self, training_files, segment_size, n_fft, num_mels,
                 hop_size, win_size, sampling_rate,  fmin, fmax, split=True, shuffle=True, n_cache_reuse=1,
                 device=None, fmax_loss=None, fine_tuning=False, base_mels_path=None):
        self.audio_files = training_files
        random.seed(1234)
        if shuffle:
            random.shuffle(self.audio_files)
        self.segment_size = segment_size
        self.sampling_rate = sampling_rate
        self.split = split
        self.n_fft = n_fft
        self.num_mels = num_mels
        self.hop_size = hop_size
        self.win_size = win_size
        self.fmin = fmin
        self.fmax = fmax
        self.fmax_loss = fmax_loss
        self.cached_wav = None
        self.n_cache_reuse = n_cache_reuse
        self._cache_ref_count = 0
        self.device = device
        self.fine_tuning = fine_tuning
        self.base_mels_path = base_mels_path

    def __getitem__(self, index):
        filename = self.audio_files[index]
        if self._cache_ref_count == 0:
            audio, sampling_rate = load_wav(filename)
            audio = audio / MAX_WAV_VALUE
            if not self.fine_tuning:
                audio = normalize(audio) * 0.95
            self.cached_wav = audio
            if sampling_rate != self.sampling_rate:
                raise ValueError(f"{sampling_rate} SR doesn't match target {self.sampling_rate} SR")
            self._cache_ref_count = self.n_cache_reuse
        else:
            audio = self.cached_wav
            self._cache_ref_count -= 1

        audio = torch.FloatTensor(audio).unsqueeze(0)

        if not self.fine_tuning:  # self.fine_tuning : False
            if self.split:
                if audio.size(1) >= self.segment_size:
                    max_audio_start = audio.size(1) - self.segment_size
                    audio_start = random.randint(0, max_audio_start)
                    audio = audio[:, audio_start:audio_start+self.segment_size]
                else:
                    audio = torch.nn.functional.pad(audio, (0, self.segment_size - audio.size(1)), 'constant')

            mel = mel_spectrogram(audio, self.n_fft, self.num_mels,
                                  self.sampling_rate, self.hop_size, self.win_size, self.fmin, self.fmax,
                                  center=False)
        else:
            mel = np.load(
                os.path.join(self.base_mels_path, os.path.splitext(os.path.split(filename)[-1])[0] + '.npy'))
            mel = torch.from_numpy(mel)

            if len(mel.shape) < 3:
                mel = mel.unsqueeze(0)

            if self.split:
                frames_per_seg = math.ceil(self.segment_size / self.hop_size)

                if audio.size(1) >= self.segment_size:
                    mel_start = random.randint(0, mel.size(2) - frames_per_seg - 1)
                    mel = mel[:, :, mel_start:mel_start + frames_per_seg]
                    audio = audio[:, mel_start * self.hop_size:(mel_start + frames_per_seg) * self.hop_size]
                else:
                    mel = torch.nn.functional.pad(mel, (0, frames_per_seg - mel.size(2)), 'constant')
                    audio = torch.nn.functional.pad(audio, (0, self.segment_size - audio.size(1)), 'constant')

        mel_loss = mel_spectrogram(audio, self.n_fft, self.num_mels,
                                   self.sampling_rate, self.hop_size, self.win_size, self.fmin, self.fmax_loss,
                                   center=False)

        return (mel.squeeze(), audio.squeeze(0), filename, mel_loss.squeeze())

    def __len__(self):
        return len(self.audio_files)

# %% [markdown]
# ## hifi-model

# %%
#model
import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.nn import Conv1d, ConvTranspose1d, AvgPool1d, Conv2d
from torch.nn.utils import weight_norm, remove_weight_norm, spectral_norm

LRELU_SLOPE = 0.2


class ResBlock1(torch.nn.Module):
    def __init__(self, h, channels, kernel_size=3, dilation=(1, 3, 5)):
        super(ResBlock1, self).__init__()
        self.h = h
        self.convs1 = nn.ModuleList([
            weight_norm(Conv1d(channels, channels, kernel_size, 1, dilation=dilation[0],
                               padding=get_padding(kernel_size, dilation[0]))),
            weight_norm(Conv1d(channels, channels, kernel_size, 1, dilation=dilation[1],
                               padding=get_padding(kernel_size, dilation[1]))),
            weight_norm(Conv1d(channels, channels, kernel_size, 1, dilation=dilation[2],
                               padding=get_padding(kernel_size, dilation[2])))
        ])
        self.convs1.apply(init_weights)

        self.convs2 = nn.ModuleList([
            weight_norm(Conv1d(channels, channels, kernel_size, 1, dilation=1,
                               padding=get_padding(kernel_size, 1))),
            weight_norm(Conv1d(channels, channels, kernel_size, 1, dilation=1,
                               padding=get_padding(kernel_size, 1))),
            weight_norm(Conv1d(channels, channels, kernel_size, 1, dilation=1,
                               padding=get_padding(kernel_size, 1)))
        ])
        self.convs2.apply(init_weights)

    def forward(self, x):
        for c1, c2 in zip(self.convs1, self.convs2):
            xt = F.leaky_relu(x, LRELU_SLOPE)
            xt = c1(xt)
            xt = F.leaky_relu(xt, LRELU_SLOPE)
            xt = c2(xt)
            x = xt + x
        return x

    def remove_weight_norm(self):
        for l in self.convs1:
            remove_weight_norm(l)
        for l in self.convs2:
            remove_weight_norm(l)


class ResBlock2(torch.nn.Module):
    def __init__(self, h, channels, kernel_size=3, dilation=(1, 3)):
        super(ResBlock2, self).__init__()
        self.h = h
        self.convs = nn.ModuleList([
            weight_norm(Conv1d(channels, channels, kernel_size, 1, dilation=dilation[0],
                               padding=get_padding(kernel_size, dilation[0]))),
            weight_norm(Conv1d(channels, channels, kernel_size, 1, dilation=dilation[1],
                               padding=get_padding(kernel_size, dilation[1])))
        ])
        self.convs.apply(init_weights)

    def forward(self, x):
        for c in self.convs:
            xt = F.leaky_relu(x, LRELU_SLOPE)
            xt = c(xt)
            x = xt + x
        return x

    def remove_weight_norm(self):
        for l in self.convs:
            remove_weight_norm(l)


class Generator(torch.nn.Module):
    def __init__(self, h):
        super(Generator, self).__init__()
        self.h = h
        self.num_kernels = len(h.resblock_kernel_sizes)
        self.num_upsamples = len(h.upsample_rates)
        self.conv_pre = weight_norm(Conv1d(80, h.upsample_initial_channel, 7, 1, padding=3))
        resblock = ResBlock1 if h.resblock == '1' else ResBlock2

        self.ups = nn.ModuleList()
        for i, (u, k) in enumerate(zip(h.upsample_rates, h.upsample_kernel_sizes)):
            self.ups.append(weight_norm(
                ConvTranspose1d(h.upsample_initial_channel//(2**i), h.upsample_initial_channel//(2**(i+1)),
                                k, u, padding=(k-u)//2)))

        self.resblocks = nn.ModuleList()
        for i in range(len(self.ups)):
            ch = h.upsample_initial_channel//(2**(i+1))
            for j, (k, d) in enumerate(zip(h.resblock_kernel_sizes, h.resblock_dilation_sizes)):
                self.resblocks.append(resblock(h, ch, k, d))

        self.conv_post = weight_norm(Conv1d(ch, 1, 7, 1, padding=3))
        self.ups.apply(init_weights)
        self.conv_post.apply(init_weights)

    def forward(self, x):
        x = self.conv_pre(x)
        for i in range(self.num_upsamples):
            x = F.leaky_relu(x, LRELU_SLOPE)
            x = self.ups[i](x)
            xs = None
            for j in range(self.num_kernels):
                if xs is None:
                    xs = self.resblocks[i*self.num_kernels+j](x)
                else:
                    xs += self.resblocks[i*self.num_kernels+j](x)
            x = xs / self.num_kernels
        x = F.leaky_relu(x)
        x = self.conv_post(x)
        x = torch.tanh(x)

        return x

    def remove_weight_norm(self):
        print('Removing weight norm...')
        for l in self.ups:
            remove_weight_norm(l)
        for l in self.resblocks:
            l.remove_weight_norm()
        remove_weight_norm(self.conv_pre)
        remove_weight_norm(self.conv_post)


    def summary(self, input_shape):
        """ 모델 구조를 출력하는 summary 메서드 추가 """
        return summary(self, input_size=input_shape, verbose=2)


class DiscriminatorP(torch.nn.Module):
    def __init__(self, period, kernel_size=5, stride=3, use_spectral_norm=False):
        super(DiscriminatorP, self).__init__()
        self.period = period
        norm_f = weight_norm if use_spectral_norm == False else spectral_norm
        self.convs = nn.ModuleList([
            norm_f(Conv2d(1, 32, (kernel_size, 1), (stride, 1), padding=(get_padding(5, 1), 0))),
            norm_f(Conv2d(32, 128, (kernel_size, 1), (stride, 1), padding=(get_padding(5, 1), 0))),
            norm_f(Conv2d(128, 512, (kernel_size, 1), (stride, 1), padding=(get_padding(5, 1), 0))),
            norm_f(Conv2d(512, 1024, (kernel_size, 1), (stride, 1), padding=(get_padding(5, 1), 0))),
            norm_f(Conv2d(1024, 1024, (kernel_size, 1), 1, padding=(2, 0))),
        ])
        self.conv_post = norm_f(Conv2d(1024, 1, (3, 1), 1, padding=(1, 0)))

    def forward(self, x):
        fmap = []

        # 1d to 2d
        b, c, t = x.shape
        if t % self.period != 0: # pad first
            n_pad = self.period - (t % self.period)
            x = F.pad(x, (0, n_pad), "reflect")
            t = t + n_pad
        x = x.view(b, c, t // self.period, self.period)

        for l in self.convs:
            x = l(x)
            x = F.leaky_relu(x, LRELU_SLOPE)
            fmap.append(x)
        x = self.conv_post(x)
        fmap.append(x)
        x = torch.flatten(x, 1, -1)

        return x, fmap

class MultiPeriodDiscriminator(torch.nn.Module):
    def __init__(self):
        super(MultiPeriodDiscriminator, self).__init__()
        self.discriminators = nn.ModuleList([
            DiscriminatorP(2),
            DiscriminatorP(3),
            DiscriminatorP(5),
            DiscriminatorP(7),
            DiscriminatorP(11),
            #레이어 추가
            DiscriminatorP(13), #1600만
            DiscriminatorP(17),
            DiscriminatorP(19),
        ])

    def forward(self, y, y_hat):
        y_d_rs = []
        y_d_gs = []
        fmap_rs = []
        fmap_gs = []
        for i, d in enumerate(self.discriminators):
            y_d_r, fmap_r = d(y)
            y_d_g, fmap_g = d(y_hat)
            y_d_rs.append(y_d_r)
            fmap_rs.append(fmap_r)
            y_d_gs.append(y_d_g)
            fmap_gs.append(fmap_g)

        return y_d_rs, y_d_gs, fmap_rs, fmap_gs

    def summary(self, input_shape):
        """ MPD 모델 구조를 출력하는 summary 메서드 추가 """
        return summary(self, input_size=[input_shape, input_shape], verbose=2)

class DiscriminatorS(torch.nn.Module):
    def __init__(self, use_spectral_norm=False):
        super(DiscriminatorS, self).__init__()
        norm_f = weight_norm if use_spectral_norm == False else spectral_norm
        self.convs = nn.ModuleList([
            norm_f(Conv1d(1, 128, 15, 1, padding=7)),
            norm_f(Conv1d(128, 128, 41, 2, groups=4, padding=20)),
            norm_f(Conv1d(128, 256, 41, 2, groups=16, padding=20)),
            norm_f(Conv1d(256, 512, 41, 4, groups=16, padding=20)),
            norm_f(Conv1d(512, 1024, 41, 4, groups=16, padding=20)),
            norm_f(Conv1d(1024, 1024, 41, 1, groups=16, padding=20)),
            norm_f(Conv1d(1024, 1024, 5, 1, padding=2)),
        ])
        self.conv_post = norm_f(Conv1d(1024, 1, 3, 1, padding=1))

    def forward(self, x):
        fmap = []
        for l in self.convs:
            x = l(x)
            x = F.leaky_relu(x, LRELU_SLOPE)
            fmap.append(x)
        x = self.conv_post(x)
        fmap.append(x)
        x = torch.flatten(x, 1, -1)

        return x, fmap



class MultiScaleDiscriminator(torch.nn.Module):
    def __init__(self):
        super(MultiScaleDiscriminator, self).__init__()
        self.discriminators = nn.ModuleList([
            DiscriminatorS(use_spectral_norm=True),
            DiscriminatorS(),
            DiscriminatorS(),
            #레이어 3개 추가
            DiscriminatorS(),# 3000만
            DiscriminatorS(),
            DiscriminatorS(),

        ])
        self.meanpools = nn.ModuleList([
            AvgPool1d(4, 2, padding=2),
            AvgPool1d(4, 2, padding=2),
            # #레이어 3개 추가
            AvgPool1d(4, 2, padding=2),
            AvgPool1d(4, 2, padding=2),
            AvgPool1d(4, 2, padding=2),
        ])

    def forward(self, y, y_hat):
        y_d_rs = []
        y_d_gs = []
        fmap_rs = []
        fmap_gs = []
        for i, d in enumerate(self.discriminators):
            if i != 0:
                y = self.meanpools[i-1](y)
                y_hat = self.meanpools[i-1](y_hat)
            y_d_r, fmap_r = d(y)
            y_d_g, fmap_g = d(y_hat)
            y_d_rs.append(y_d_r)
            fmap_rs.append(fmap_r)
            y_d_gs.append(y_d_g)
            fmap_gs.append(fmap_g)

        return y_d_rs, y_d_gs, fmap_rs, fmap_gs

    def summary(self, input_shape):
        """ MSD 모델 구조를 출력하는 summary 메서드 추가 """
        return summary(self, input_size=[input_shape, input_shape], verbose=2)

# %% [markdown]
# # hifi - train

# %%
import wandb
os.environ["WANDB_API_KEY"] = "6ba73968f6dbad6493330f80a9ddda172aada054"
wandb.login()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: spdlxmvmfl (spdlxmvmfl-korea-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# WandB 프로젝트 초기화
name = "RPGAN_R1R2_lambda(0.0005)_G0D3"   # ex) WGAN (노션 참고)
id = 'rpgan_r1r2_lambda0.0005_G0D3'     # 프로젝트마다 고유 id 부여 (실험마다 다르게 설정해야함, 만약 전 실험을 이어서 진행하고 싶다면 같은 id 기재)
wandb.init(project="RPGAN_R1R2_LAMBDA_G0D3", name=name ,id = id, resume = 'allow',settings=wandb.Settings(init_timeout=1200))
# Out:
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/content/drive/MyDrive/코딩공부/deep_daiv/PAPER_SUBMIT/wandb/run-20250307_084242-rpgan_r1r2_lambda0.0005_G0D3</code>
# Resuming run <strong><a href='https://wandb.ai/spdlxmvmfl-korea-university/RPGAN_R1R2_LAMBDA_G0D3/runs/rpgan_r1r2_lambda0.0005_G0D3' target="_blank">RPGAN_R1R2_lambda(0.0005)_G0D3</a></strong> to <a href='https://wandb.ai/spdlxmvmfl-korea-university/RPGAN_R1R2_LAMBDA_G0D3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/spdlxmvmfl-korea-university/RPGAN_R1R2_LAMBDA_G0D3' target="_blank">https://wandb.ai/spdlxmvmfl-korea-university/RPGAN_R1R2_LAMBDA_G0D3</a>
#  View run at <a href='https://wandb.ai/spdlxmvmfl-korea-university/RPGAN_R1R2_LAMBDA_G0D3/runs/rpgan_r1r2_lambda0.0005_G0D3' target="_blank">https://wandb.ai/spdlxmvmfl-korea-university/RPGAN_R1R2_LAMBDA_G0D3/runs/rpgan_r1r2_lambda0.0005_G0D3</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/spdlxmvmfl-korea-university/RPGAN_R1R2_LAMBDA_G0D3/runs/rpgan_r1r2_lambda0.0005_G0D3?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# ## Loss

# %% [markdown]
# RPGAN Loss

# %%
def feature_loss(fmap_r, fmap_g):
    loss = 0
    for dr, dg in zip(fmap_r, fmap_g):
        for rl, gl in zip(dr, dg):
            loss += torch.mean(torch.abs(rl - gl))

    return loss*2

'''
def discriminator_loss(disc_real_outputs, disc_generated_outputs):
    loss = 0
    r_losses = []
    g_losses = []
    for dr, dg in zip(disc_real_outputs, disc_generated_outputs):
        r_loss = torch.mean((1-dr)**2)
        g_loss = torch.mean(dg**2)
        loss += (r_loss + g_loss)
        r_losses.append(r_loss.item())
        g_losses.append(g_loss.item())

    return loss, r_losses, g_losses


def generator_loss(disc_outputs):
    loss = 0
    gen_losses = []
    for dg in disc_outputs:
        l = torch.mean((1-dg)**2)
        gen_losses.append(l)
        loss += l

    return loss, gen_losses
'''

def discriminator_loss(disc_real_outputs, disc_generated_outputs): #모양 바꿈
     loss = 0
     for dr, dg in zip(disc_real_outputs, disc_generated_outputs):
         relativistic_logits = dr - dg
         loss += torch.mean(F.softplus(-relativistic_logits))
     return loss

def generator_loss(disc_real_outputs, disc_generated_outputs): #discriminator가 뱉은 값을 받아서 업뎃을 해야지
     loss = 0
     for dr, dg in zip(disc_real_outputs, disc_generated_outputs):
         relativistic_logits = dr - dg
         loss += torch.mean(F.softplus(relativistic_logits))
     return loss

# %%
from torchaudio.transforms import Resample
import tempfile
import librosa

def lsd(est ,target):
    assert est.shape == target.shape, "Spectrograms must have the same shape."
    est = est.squeeze(0).squeeze(0) ** 2
    target = target.squeeze(0).squeeze(0) ** 2
    # Compute the log of the magnitude spectrograms (adding a small epsilon to avoid log(0))
    epsilon = 1e-10
    log_spectrogram1 = torch.log10(target + epsilon)
    log_spectrogram2 = torch.log10(est + epsilon)
    squared_diff = (log_spectrogram1 - log_spectrogram2) ** 2
    squared_diff = torch.mean(squared_diff, dim = 1) ** 0.5
    lsd = torch.mean(squared_diff, dim = 0)
    return lsd

def lsd_hf(est, target, hf_ratio=0.25):
    assert est.shape == target.shape, "Spectrograms must have the same shape."
    est = est.squeeze(0).squeeze(0) ** 2
    target = target.squeeze(0).squeeze(0) ** 2

    # Define high-frequency range
    num_freq_bins = est.shape[0]
    hf_start = int(num_freq_bins * (1 - hf_ratio))  # Starting index for high frequencies

    # Focus on high-frequency bands
    est_hf = est[hf_start:, :]
    target_hf = target[hf_start:, :]

    # Compute the log of the magnitude spectrograms (adding a small epsilon to avoid log(0))
    epsilon = 1e-10
    log_spectrogram1 = torch.log10(target_hf + epsilon)
    log_spectrogram2 = torch.log10(est_hf + epsilon)
    squared_diff = (log_spectrogram1 - log_spectrogram2) ** 2
    squared_diff = torch.mean(squared_diff, dim=1) ** 0.5
    lsd_hf = torch.mean(squared_diff, dim=0)

    return lsd_hf

def extract_f0_from_audio(audio, sr, fmin=50, fmax=500):
    audio_np = audio.cpu().numpy()  # Convert to numpy for librosa
    f0, voiced_flag, _ = librosa.pyin(audio_np, fmin=fmin, fmax=fmax, sr=sr)
    f0 = torch.tensor(f0, dtype=torch.float32)  # Convert back to tensor
    f0[~torch.tensor(voiced_flag, dtype=torch.bool)] = 0  # Set unvoiced regions to 0
    return f0

def f0_rmse(f0_pred, f0_target):
    assert f0_pred.shape == f0_target.shape, "F0 shapes must match."
    squared_error = (f0_pred - f0_target) ** 2
    mse = torch.mean(squared_error)
    rmse = torch.sqrt(mse)
    return rmse

# %% [markdown]
# ## train

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import itertools
import os
import time
import argparse
import json
import torch
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import DistributedSampler, DataLoader
import torch.multiprocessing as mp
from torch.distributed import init_process_group
from torch.nn.parallel import DistributedDataParallel
import easydict
import torchaudio

torch.backends.cudnn.benchmark = True

#penalty 계산 함수
def compute_r1_penalty(discriminators, real_samples, device, gamma=0.0005):
    """
    Computes the R1 regularization penalty for each discriminator in the given discriminators list.
    Args:
        discriminators: A list of individual discriminators (DiscriminatorP or DiscriminatorS).
        real_samples: The real samples (y).
        device: The device (cuda or cpu).
        gamma: The regularization weight (default: 10.0).
    Returns:
        r1_penalty: The computed R1 penalty.
    """
    real_samples = real_samples.requires_grad_(True)  # Enable gradient tracking
    r1_penalties = []

    for d in discriminators:
        real_outputs, _ = d(real_samples)  # Get discriminator outputs for real samples
        grad_real = torch.autograd.grad(
            outputs=real_outputs.sum(),
            inputs=real_samples,
            create_graph=True, retain_graph=True, only_inputs=True
        )[0]  # Compute gradients

        r1_penalty = (grad_real.norm(2, dim=(1, 2)) ** 2).mean()  # Compute gradient norm squared and take mean
        r1_penalties.append(r1_penalty)

    return (gamma / 2) * sum(r1_penalties)  # Apply weighting factor

def compute_r2_penalty(discriminators, fake_samples, device, gamma=0.0005):
    """
    Computes the R2 regularization penalty for each discriminator in the given discriminators list.
    Args:
        discriminators: A list of individual discriminators (DiscriminatorP or DiscriminatorS).
        fake_samples: The fake samples (generated by the generator).
        device: The device (cuda or cpu).
        gamma: The regularization weight (default: 10.0).
    Returns:
        r2_penalty: The computed R2 penalty.
    """
    fake_samples = fake_samples.requires_grad_(True)  # Enable gradient tracking
    r2_penalties = []

    for d in discriminators:
        fake_outputs, _ = d(fake_samples)  # Get discriminator outputs for fake samples
        grad_fake = torch.autograd.grad(
            outputs=fake_outputs.sum(),
            inputs=fake_samples,
            create_graph=True, retain_graph=True, only_inputs=True
        )[0]  # Compute gradients

        r2_penalty = (grad_fake.norm(2, dim=(1, 2)) ** 2).mean()  # Compute gradient norm squared and take mean
        r2_penalties.append(r2_penalty)

    return (gamma / 2) * sum(r2_penalties)  # Apply weighting factor

def train(rank, a, h): # rank : 0
    # SCOREQ 초기화
    scoreq_nr = scoreq.Scoreq(data_domain='natural', mode='nr')  # No-reference

    # PESQ 초기화
    pesq = PesqLoss(0.5,h.sampling_rate).eval()
    for param in pesq.parameters():
      param.requires_grad = False

    # # lambda 값 설정
    # ex) loss_scale_formant = 0.001
    # ex) loss_scale_r1r2 = #

    if h.num_gpus > 1:
        init_process_group(backend=h.dist_config['dist_backend'], init_method=h.dist_config['dist_url'],
                           world_size=h.dist_config['world_size'] * h.num_gpus, rank=rank)

    torch.cuda.manual_seed(h.seed)
    device = torch.device('cuda:{:d}'.format(rank))

    generator = Generator(h).to(device)

    mpd = MultiPeriodDiscriminator().to(device)
    msd = MultiScaleDiscriminator().to(device)

    if rank == 0:
        os.makedirs(a.checkpoint_path, exist_ok=True)
        print("checkpoints directory : ", a.checkpoint_path)
        #크기 보기
        # print("\n========== Generator Model ==========")
        # generator.summary(input_shape=(1, h.num_mels, h.segment_size // h.hop_size))  # ✅ model.summary()처럼 사용 가능!

        # print("\n========== Multi-Period Discriminator (MPD) ==========")
        # mpd.summary(input_shape=(1, 1, h.segment_size))  # ✅ 입력 2개 전달

        # print("\n========== Multi-Scale Discriminator (MSD) ==========")
        # msd.summary(input_shape=(1, 1, h.segment_size))  # ✅ 입력 2개 전달

    if os.path.isdir(a.checkpoint_path):                 # 만약 체크포인트 폴더에 g_ 또는 do_로 시작하는 파일이 있다면 체크포인트 로드됨.
        cp_g = scan_checkpoint(a.checkpoint_path, 'g_')
        cp_do = scan_checkpoint(a.checkpoint_path, 'do_')

    steps = 0
    if cp_g is None or cp_do is None:         # 처음부터 학습
        state_dict_do = None
        last_epoch = -1
    else:                                     # 체크포인트부터 학습
        state_dict_g = load_checkpoint(cp_g, device)
        state_dict_do = load_checkpoint(cp_do, device)
        generator.load_state_dict(state_dict_g['generator'])
        mpd.load_state_dict(state_dict_do['mpd'])
        msd.load_state_dict(state_dict_do['msd'])
        steps = state_dict_do['steps'] + 1
        last_epoch = state_dict_do['epoch']

    if h.num_gpus > 1:
        generator = DistributedDataParallel(generator, device_ids=[rank]).to(device)
        mpd = DistributedDataParallel(mpd, device_ids=[rank]).to(device)
        msd = DistributedDataParallel(msd, device_ids=[rank]).to(device)


    # 옵티마이저 변경(?) - 후보 SGD, MOMENTUM, ADAM
    optim_g = torch.optim.AdamW(generator.parameters(), h.learning_rate, betas=[h.adam_b1, h.adam_b2])
    optim_d = torch.optim.AdamW(itertools.chain(msd.parameters(), mpd.parameters()),
                                h.learning_rate, betas=[h.adam_b1, h.adam_b2])

    if state_dict_do is not None:
        optim_g.load_state_dict(state_dict_do['optim_g'])
        optim_d.load_state_dict(state_dict_do['optim_d'])

    scheduler_g = torch.optim.lr_scheduler.ExponentialLR(optim_g, gamma=h.lr_decay, last_epoch=last_epoch)
    scheduler_d = torch.optim.lr_scheduler.ExponentialLR(optim_d, gamma=h.lr_decay, last_epoch=last_epoch)

    training_filelist, validation_filelist = get_dataset_filelist(a)

    trainset = MelDataset(training_filelist, h.segment_size, h.n_fft, h.num_mels,
                          h.hop_size, h.win_size, h.sampling_rate, h.fmin, h.fmax, n_cache_reuse=0,
                          shuffle=False if h.num_gpus > 1 else True, fmax_loss=h.fmax_for_loss, device=device,
                          fine_tuning=a.fine_tuning, base_mels_path=a.input_mels_dir)

    train_sampler = DistributedSampler(trainset) if h.num_gpus > 1 else None

    train_loader = DataLoader(trainset, num_workers=h.num_workers, shuffle=False,
                              sampler=train_sampler,
                              batch_size=h.batch_size,
                              pin_memory=True,
                              drop_last=True)

    if rank == 0:
        validset = MelDataset(validation_filelist, h.segment_size, h.n_fft, h.num_mels,
                              h.hop_size, h.win_size, h.sampling_rate, h.fmin, h.fmax, False, False, n_cache_reuse=0,
                              fmax_loss=h.fmax_for_loss, device=device, fine_tuning=a.fine_tuning,
                              base_mels_path=a.input_mels_dir)
        validation_loader = DataLoader(validset, num_workers=1, shuffle=False,
                                       sampler=None,
                                       batch_size=1,
                                       pin_memory=True,
                                       drop_last=True)

        sw = SummaryWriter(os.path.join(a.checkpoint_path, 'logs'))


    generator.train()
    mpd.train()
    msd.train()
    for epoch in range(max(0, last_epoch), a.training_epochs):  # 200 epoch
        if rank == 0:
            start = time.time()
            print("Epoch: {}".format(epoch+1))

        if h.num_gpus > 1:
            train_sampler.set_epoch(epoch)

        for i, batch in enumerate(train_loader):
            if rank == 0:
                start_b = time.time()
            x, y, _, y_mel = batch
            x = torch.autograd.Variable(x.to(device, non_blocking=True))
            y = torch.autograd.Variable(y.to(device, non_blocking=True))
            y_mel = torch.autograd.Variable(y_mel.to(device, non_blocking=True))
            y = y.unsqueeze(1)

            y_g_hat = generator(x)
            y_g_hat_mel = mel_spectrogram(y_g_hat.squeeze(1), h.n_fft, h.num_mels, h.sampling_rate, h.hop_size, h.win_size,
                                          h.fmin, h.fmax_for_loss)

            optim_d.zero_grad()

            # MPD
            y_df_hat_r, y_df_hat_g, _, _ = mpd(y, y_g_hat.detach())
            loss_disc_f = discriminator_loss(y_df_hat_r, y_df_hat_g)

            # MSD
            y_ds_hat_r, y_ds_hat_g, _, _ = msd(y, y_g_hat.detach())
            loss_disc_s = discriminator_loss(y_ds_hat_r, y_ds_hat_g)

            #R1 Penalty 추가
            # ✅ MPD & MSD 각각의 Discriminators 리스트를 전달
            r1_penalty_mpd = compute_r1_penalty(mpd.discriminators, y, device, gamma=1)
            r1_penalty_msd = compute_r1_penalty(msd.discriminators, y, device, gamma=1)

            r2_penalty_mpd = compute_r2_penalty(mpd.discriminators, y_g_hat.detach(), device, gamma=1)
            r2_penalty_msd = compute_r2_penalty(msd.discriminators, y_g_hat.detach(), device, gamma=1)

            # ✅ 최종 Discriminator Loss 계산 (R1 + R2 Penalty 포함)
            loss_disc_all = loss_disc_s + loss_disc_f + r1_penalty_mpd + r1_penalty_msd + r2_penalty_mpd + r2_penalty_msd
            wandb.log({"train/loss_disc_all" : loss_disc_all , "train/loss_disc_f" : loss_disc_f , "train/loss_disc_s " : loss_disc_s ,
                       "train/r1_penalty_mpd": r1_penalty_mpd, "train/r1_penalty_msd": r1_penalty_msd, "train/r2_penalty_mpd": r2_penalty_mpd, "train/r2_penalty_msd": r2_penalty_msd})

            loss_disc_all.backward()
            optim_d.step()

            # Generator
            optim_g.zero_grad()

            # L1 Mel-Spectrogram Loss
            loss_mel = F.l1_loss(y_mel, y_g_hat_mel) * 45

            y_df_hat_r, y_df_hat_g, fmap_f_r, fmap_f_g = mpd(y, y_g_hat)
            y_ds_hat_r, y_ds_hat_g, fmap_s_r, fmap_s_g = msd(y, y_g_hat)
            loss_fm_f = feature_loss(fmap_f_r, fmap_f_g)
            loss_fm_s = feature_loss(fmap_s_r, fmap_s_g)
            loss_gen_f = generator_loss(y_df_hat_r,y_df_hat_g)
            loss_gen_s = generator_loss(y_ds_hat_r, y_ds_hat_g)

            loss_gen_all = loss_gen_s + loss_gen_f + loss_fm_s + loss_fm_f + loss_mel   # generator loss 계산
            wandb.log({"train/loss_gen_all" : loss_gen_all , "train/loss_gen_s" : loss_gen_s , "train/loss_gen_f" : loss_gen_f,
                       "train/loss_fm_s" : loss_fm_s , "train/loss_fm_f" : loss_fm_f , "train/loss_mel" : loss_mel})

            loss_gen_all.backward()
            optim_g.step()

            if rank == 0:
                # STDOUT logging
                if steps % a.stdout_interval == 0:
                    with torch.no_grad():
                        mel_error = F.l1_loss(y_mel, y_g_hat_mel).item()

                    print('Steps : {:d}, Gen Loss Total : {:4.3f}, Mel-Spec. Error : {:4.3f}, s/b : {:4.3f}'.
                          format(steps, loss_gen_all, mel_error, time.time() - start_b))

                # checkpointing
                if steps % a.checkpoint_interval == 0 and steps != 0:
                    checkpoint_path = "{}/g_{:08d}".format(a.checkpoint_path, steps)
                    save_checkpoint(checkpoint_path,
                                    {'generator': (generator.module if h.num_gpus > 1 else generator).state_dict()})
                    checkpoint_path = "{}/do_{:08d}".format(a.checkpoint_path, steps)
                    save_checkpoint(checkpoint_path,
                                    {'mpd': (mpd.module if h.num_gpus > 1
                                                         else mpd).state_dict(),
                                     'msd': (msd.module if h.num_gpus > 1
                                                         else msd).state_dict(),
                                     'optim_g': optim_g.state_dict(), 'optim_d': optim_d.state_dict(), 'steps': steps,
                                     'epoch': epoch})

                # # Tensorboard summary logging
                # if steps % a.summary_interval == 0:
                #     sw.add_scalar("training/gen_loss_total", loss_gen_all, steps)
                #     sw.add_scalar("training/mel_spec_error", mel_error, steps)

                # Validation
                if steps % a.validation_interval == 0 and steps != 0:
                    generator.eval()
                    torch.cuda.empty_cache()

                    val_err_tot = 0
                    val_err_tot_rmse = 0
                    val_err_tot_f0rmse = 0
                    val_err_tot_lsd = 0
                    val_err_tot_lsd_hf = 0
                    val_err_tot_mos = 0

                    with torch.no_grad():
                        for j, batch in enumerate(validation_loader):
                            x, y, _, y_mel = batch
                            y_g_hat = generator(x.to(device))
                            y_mel = torch.autograd.Variable(y_mel.to(device, non_blocking=True))
                            y_g_hat_mel = mel_spectrogram(y_g_hat.squeeze(1), h.n_fft, h.num_mels, h.sampling_rate,
                                                          h.hop_size, h.win_size,
                                                          h.fmin, h.fmax_for_loss)
                            # L1 loss 계산
                            val_err_tot += F.l1_loss(y_mel, y_g_hat_mel).item()

                            # RMSE 계산
                            val_err_tot_rmse += torch.sqrt(F.mse_loss(y_g_hat_mel, y_mel, reduction='mean')).item()

                            # F0_RMSE 계산
                            f0_y = extract_f0_from_audio(y.squeeze(1), h.sampling_rate)
                            f0_y_g_hat = extract_f0_from_audio(y_g_hat.squeeze(1), h.sampling_rate)
                            val_err_tot_f0rmse += f0_rmse(f0_y_g_hat, f0_y).item()

                            # LSD
                            val_err_tot_lsd += lsd(y_g_hat_mel,  y_mel).item()

                            # LSD_HF
                            val_err_tot_lsd_hf += lsd_hf(y_g_hat_mel,  y_mel).item()

                            # SCOREQ 계산
                            # 참조 및 생성된 오디오를 파일로 저장 (SCOREQ는 파일 경로로 입력 받음)
                            test_audio_path = f"temp_test.wav"
                            torchaudio.save(test_audio_path, y_g_hat.squeeze(1).cpu(), h.sampling_rate)

                            # No-reference 모드에서 품질 평가
                            val_err_tot_mos += scoreq_nr.predict(test_path=test_audio_path).item()

                            if j <= 4:
                                if steps != 0:
                                    wandb.log({
                                        "Predicted Audio": wandb.Audio(
                                        y_g_hat.squeeze().cpu().numpy(),
                                        sample_rate=h.sampling_rate,
                                        caption="Predicted Audio"
                                    ),
                                    "Ground Truth Audio": wandb.Audio(
                                        y[0].squeeze().cpu().numpy(),
                                        sample_rate=h.sampling_rate,
                                        caption="Ground Truth Audio"
                                    )})

                                # sw.add_audio('generated/y_hat_{}'.format(j), y_g_hat[0], steps, h.sampling_rate)
                                y_hat_spec = mel_spectrogram(y_g_hat.squeeze(1), h.n_fft, h.num_mels,
                                                             h.sampling_rate, h.hop_size, h.win_size,
                                                             h.fmin, h.fmax)
                                wandb.log({'generated/y_hat_spec_{}'.format(j):
                                              plot_spectrogram(y_hat_spec.squeeze(0).cpu().numpy())})

                        val_err_l1 = val_err_tot / (j+1)
                        val_err_rmse = val_err_tot_rmse / (j+1)
                        val_err_f0rmse = val_err_tot_f0rmse / (j+1)
                        val_err_lsd = val_err_tot_lsd / (j+1)
                        val_err_lsd_hf = val_err_tot_lsd_hf / (j+1)
                        val_err_mos = val_err_tot_mos / (j+1)

                        wandb.log({"validation/val_err_l1": val_err_l1, "validation/val_err_rmse": val_err_rmse, "validation/val_err_f0rmse": val_err_f0rmse,
                                   "validation/val_err_lsd": val_err_lsd, "validation/val_err_lsd_hf": val_err_lsd_hf, "validation/val_err_mos": val_err_mos})

                    generator.train()

            steps += 1

        scheduler_g.step()
        scheduler_d.step()

        if rank == 0:
            print('Time taken for epoch {} is {} sec\n'.format(epoch + 1, int(time.time() - start)))


def main():
    print('Initializing Training Process..')

    a = easydict.EasyDict({
      "group_name" : None,
      "input_wavs_dir" : 'LJSpeech-1.1/wavs',
      "input_mels_dir" : None,                              # fine-tuning 안할거면 필요 없음
      "input_training_file" : 'LJSpeech-1.1/training.txt',
      "input_validation_file" : 'LJSpeech-1.1/validation.txt',
      "checkpoint_path" : 'cp_RPGAN_R1R2_lambda(0.0005)_G0D3',                     # 체크포인트 폴더명 지정 (cp_Wandb name이랑 똑같이 설정 -> ex) cp_WGAN )
      "config" : 'config_v3.json',
      "training_epochs" : 50,
      "stdout_interval" : 50,
      "checkpoint_interval" : 1000,
      "summary_interval" : 100,
      "validation_interval" : 1000,
      "fine_tuning" : False
      })


    with open(a.config) as f:
        data = f.read()

    json_config = json.loads(data)
    h = AttrDict(json_config)
    build_env(a.config, 'config.json', a.checkpoint_path)

    torch.manual_seed(h.seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(h.seed)
        h.num_gpus = torch.cuda.device_count()
        h.batch_size = int(h.batch_size / h.num_gpus)
        print('Batch size per GPU :', h.batch_size)
    else:
        pass

    if h.num_gpus > 1:
        mp.spawn(train, nprocs=h.num_gpus, args=(a, h,))
    else:
        train(0, a, h)
        wandb.finish()

# %%
import logging
logging.getLogger().setLevel(logging.ERROR)

# %%
if __name__ == '__main__':
  # a = Args()
  main()
# Out:
# Initializing Training Process..
# Batch size per GPU : 16
# SCOREQ running on: cuda
# /usr/local/lib/python3.11/dist-packages/hydra/experimental/initialize.py:43: UserWarning: hydra.experimental.initialize() is no longer experimental. Use hydra.initialize()
#   deprecation_warning(message=message)
# /usr/local/lib/python3.11/dist-packages/hydra/experimental/initialize.py:45: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   self.delegate = real_initialize(
# /usr/local/lib/python3.11/dist-packages/hydra/experimental/compose.py:25: UserWarning: hydra.experimental.compose() is no longer experimental. Use hydra.compose()
#   deprecation_warning(message=message)
# /usr/local/lib/python3.11/dist-packages/hydra/core/default_element.py:124: UserWarning: In 'config': Usage of deprecated keyword in package header '# @package _group_'.
# See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/changes_to_package_header for more information
#   deprecation_warning(
# /usr/local/lib/python3.11/dist-packages/fairseq/checkpoint_utils.py:432: UserWarning:
# 'config' is validated against ConfigStore schema with the same name.
# This behavior is deprecated in Hydra 1.1 and will be removed in Hydra 1.2.
# See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/automatic_schema_matching for migration instructions.
#   state = load_checkpoint_to_cpu(filename, arg_overrides)
# /usr/local/lib/python3.11/dist-packages/hydra/compose.py:56: UserWarning:
# The strict flag in the compose API is deprecated.
# See https://hydra.cc/docs/1.2/upgrades/0.11_to_1.0/strict_mode_flag_deprecated for more info.
#
#   deprecation_warning(
# <ipython-input-14-999f85302cd4>:77: UserWarning:
# 'config' is validated against ConfigStore schema with the same name.
# This behavior is deprecated in Hydra 1.1 and will be removed in Hydra 1.2.
# See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/automatic_schema_matching for migration instructions.
#   scoreq_nr = scoreq.Scoreq(data_domain='natural', mode='nr')  # No-reference
# checkpoints directory :  cp_RPGAN_R1R2_lambda(0.0005)_G0D3
# Loading 'cp_RPGAN_R1R2_lambda(0.0005)_G0D3/g_00034000'
# Complete.
# Loading 'cp_RPGAN_R1R2_lambda(0.0005)_G0D3/do_00033000'
# Complete.
# Epoch: 40
# Steps : 33050, Gen Loss Total : 35.627, Mel-Spec. Error : 0.404, s/b : 1.055
# Steps : 33100, Gen Loss Total : 34.950, Mel-Spec. Error : 0.383, s/b : 1.068
# Steps : 33150, Gen Loss Total : 35.159, Mel-Spec. Error : 0.377, s/b : 1.056
# Steps : 33200, Gen Loss Total : 38.170, Mel-Spec. Error : 0.379, s/b : 1.058
# Steps : 33250, Gen Loss Total : 36.598, Mel-Spec. Error : 0.393, s/b : 1.057
# Steps : 33300, Gen Loss Total : 36.547, Mel-Spec. Error : 0.383, s/b : 1.056
# Steps : 33350, Gen Loss Total : 35.272, Mel-Spec. Error : 0.381, s/b : 1.052
# Steps : 33400, Gen Loss Total : 35.066, Mel-Spec. Error : 0.391, s/b : 1.061
# Steps : 33450, Gen Loss Total : 38.118, Mel-Spec. Error : 0.413, s/b : 1.063
# Steps : 33500, Gen Loss Total : 41.293, Mel-Spec. Error : 0.413, s/b : 1.059
# Steps : 33550, Gen Loss Total : 34.769, Mel-Spec. Error : 0.387, s/b : 1.072
# Steps : 33600, Gen Loss Total : 34.946, Mel-Spec. Error : 0.377, s/b : 1.064
# Steps : 33650, Gen Loss Total : 37.735, Mel-Spec. Error : 0.389, s/b : 1.053
# Steps : 33700, Gen Loss Total : 37.447, Mel-Spec. Error : 0.384, s/b : 1.069
# Steps : 33750, Gen Loss Total : 37.191, Mel-Spec. Error : 0.387, s/b : 1.060
# Steps : 33800, Gen Loss Total : 36.137, Mel-Spec. Error : 0.379, s/b : 1.063
# Time taken for epoch 40 is 1114 sec
#
# Epoch: 41
# Steps : 33850, Gen Loss Total : 35.805, Mel-Spec. Error : 0.373, s/b : 1.085
# Steps : 33900, Gen Loss Total : 34.679, Mel-Spec. Error : 0.380, s/b : 1.064
# Steps : 33950, Gen Loss Total : 39.319, Mel-Spec. Error : 0.393, s/b : 1.068
# Steps : 34000, Gen Loss Total : 34.539, Mel-Spec. Error : 0.373, s/b : 1.053
# Saving checkpoint to cp_RPGAN_R1R2_lambda(0.0005)_G0D3/g_00034000
# Complete.
# Saving checkpoint to cp_RPGAN_R1R2_lambda(0.0005)_G0D3/do_00034000
# Complete.
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4865
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3149
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4923
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.7881
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4905
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3749
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3716
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2559
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5026
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1693
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.04
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0947
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4848
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1013
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3232
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3443
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6072
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3834
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4047
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4498
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.9544
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2986
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2907
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6364
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5598
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2648
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4132
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3907
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6382
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.482
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2591
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4246
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6247
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4257
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3638
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.212
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4035
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.461
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2892
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5196
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6286
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.795
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1659
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3565
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3374
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2866
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6032
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3331
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4232
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4387
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2528
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2552
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1537
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3107
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.412
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3828
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2204
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6431
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3672
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6391
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2785
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6086
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4781
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4068
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5143
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.7016
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4548
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1197
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4754
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2495
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0032
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1653
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2249
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2637
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4447
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2501
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0613
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2819
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1672
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2609
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.8471
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4189
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.7854
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6093
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3563
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2136
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2831
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0887
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4776
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3738
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4071
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4769
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2594
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2177
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5772
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4624
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0843
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.212
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3204
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2635
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4008
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3041
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.222
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1749
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2526
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4295
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1466
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2259
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1071
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0206
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.359
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3898
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3865
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1156
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4539
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4854
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6743
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.507
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3562
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0658
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6243
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1735
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1358
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0965
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1558
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.425
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0138
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3839
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3868
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.514
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6382
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5744
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2539
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5855
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0586
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3817
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6713
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3476
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4299
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4868
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6588
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4842
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3129
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6097
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2994
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1256
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3954
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6384
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2969
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4099
# Steps : 34050, Gen Loss Total : 37.288, Mel-Spec. Error : 0.420, s/b : 1.091
# Steps : 34100, Gen Loss Total : 32.979, Mel-Spec. Error : 0.360, s/b : 1.065
# Steps : 34150, Gen Loss Total : 36.232, Mel-Spec. Error : 0.380, s/b : 1.049
# Steps : 34200, Gen Loss Total : 45.036, Mel-Spec. Error : 0.399, s/b : 1.101
# Steps : 34250, Gen Loss Total : 34.923, Mel-Spec. Error : 0.393, s/b : 1.055
# Steps : 34300, Gen Loss Total : 41.393, Mel-Spec. Error : 0.397, s/b : 1.094
# Steps : 34350, Gen Loss Total : 40.477, Mel-Spec. Error : 0.414, s/b : 1.062
# Steps : 34400, Gen Loss Total : 38.629, Mel-Spec. Error : 0.405, s/b : 1.070
# Steps : 34450, Gen Loss Total : 36.066, Mel-Spec. Error : 0.388, s/b : 1.068
# Steps : 34500, Gen Loss Total : 40.248, Mel-Spec. Error : 0.387, s/b : 1.053
# Steps : 34550, Gen Loss Total : 39.611, Mel-Spec. Error : 0.389, s/b : 1.056
# Steps : 34600, Gen Loss Total : 37.990, Mel-Spec. Error : 0.417, s/b : 1.053
# Time taken for epoch 41 is 1127 sec
#
# Epoch: 42
# Steps : 34650, Gen Loss Total : 31.826, Mel-Spec. Error : 0.364, s/b : 1.074
# Steps : 34700, Gen Loss Total : 38.273, Mel-Spec. Error : 0.405, s/b : 1.067
# Steps : 34750, Gen Loss Total : 38.920, Mel-Spec. Error : 0.384, s/b : 1.059
# Steps : 34800, Gen Loss Total : 35.599, Mel-Spec. Error : 0.386, s/b : 1.082
# Steps : 34850, Gen Loss Total : 37.354, Mel-Spec. Error : 0.383, s/b : 1.056
# Steps : 34900, Gen Loss Total : 38.034, Mel-Spec. Error : 0.408, s/b : 1.058
# Steps : 34950, Gen Loss Total : 35.486, Mel-Spec. Error : 0.396, s/b : 1.061
# Steps : 35000, Gen Loss Total : 33.692, Mel-Spec. Error : 0.375, s/b : 1.069
# Saving checkpoint to cp_RPGAN_R1R2_lambda(0.0005)_G0D3/g_00035000
# Complete.
# Saving checkpoint to cp_RPGAN_R1R2_lambda(0.0005)_G0D3/do_00035000
# Complete.
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2219
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3495
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3956
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5375
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4142
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3199
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2406
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1614
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3398
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2194
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.9761
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0649
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2229
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.9592
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2009
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2768
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6065
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2408
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3769
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.186
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.8831
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2587
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3233
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5073
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4079
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0383
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1747
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3482
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2328
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0644
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2533
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5277
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2943
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2964
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1259
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2521
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2817
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.19
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1587
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5387
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.686
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0012
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1259
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1319
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2659
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.495
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3424
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3068
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2795
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0507
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.036
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2227
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2491
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2129
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.083
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3819
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3156
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5842
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0637
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5213
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4383
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4076
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4588
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5058
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2469
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.8889
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2908
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.01
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.872
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.187
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1753
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1763
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3666
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.156
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.8289
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2707
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.8992
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0789
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.8326
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.314
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5502
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3574
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2099
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1813
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1099
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.932
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3771
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0798
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3309
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3223
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2507
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2294
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5132
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2328
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.218
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.9925
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.045
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2433
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2568
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0766
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0354
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.9146
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3623
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1503
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.208
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.202
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.8103
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.9863
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1509
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1581
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3794
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1935
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3003
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2567
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5597
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2558
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1669
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.9348
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3717
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0279
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0854
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.9796
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0789
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3459
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.142
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3996
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3041
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2896
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5629
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5866
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1207
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5667
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1501
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.321
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5042
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2392
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3474
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3751
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3754
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3359
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1934
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4505
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1579
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1149
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2436
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5194
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0095
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4213
# Steps : 35050, Gen Loss Total : 35.561, Mel-Spec. Error : 0.370, s/b : 1.058
# Steps : 35100, Gen Loss Total : 35.189, Mel-Spec. Error : 0.377, s/b : 1.063
# Steps : 35150, Gen Loss Total : 42.733, Mel-Spec. Error : 0.402, s/b : 1.073
# Steps : 35200, Gen Loss Total : 34.570, Mel-Spec. Error : 0.382, s/b : 1.065
# Steps : 35250, Gen Loss Total : 37.623, Mel-Spec. Error : 0.381, s/b : 1.062
# Steps : 35300, Gen Loss Total : 33.586, Mel-Spec. Error : 0.371, s/b : 1.054
# Steps : 35350, Gen Loss Total : 39.168, Mel-Spec. Error : 0.408, s/b : 1.057
# Steps : 35400, Gen Loss Total : 36.959, Mel-Spec. Error : 0.383, s/b : 1.053
# Time taken for epoch 42 is 1088 sec
#
# Epoch: 43
# Steps : 35450, Gen Loss Total : 32.264, Mel-Spec. Error : 0.368, s/b : 1.080
# Steps : 35500, Gen Loss Total : 38.011, Mel-Spec. Error : 0.372, s/b : 1.068
# Steps : 35550, Gen Loss Total : 37.292, Mel-Spec. Error : 0.393, s/b : 1.055
# Steps : 35600, Gen Loss Total : 37.427, Mel-Spec. Error : 0.400, s/b : 1.052
# Steps : 35650, Gen Loss Total : 33.661, Mel-Spec. Error : 0.371, s/b : 1.063
# Steps : 35700, Gen Loss Total : 37.029, Mel-Spec. Error : 0.384, s/b : 1.087
# Steps : 35750, Gen Loss Total : 36.974, Mel-Spec. Error : 0.411, s/b : 1.057
# Steps : 35800, Gen Loss Total : 35.103, Mel-Spec. Error : 0.377, s/b : 1.065
# Steps : 35850, Gen Loss Total : 37.163, Mel-Spec. Error : 0.409, s/b : 1.069
# Steps : 35900, Gen Loss Total : 35.141, Mel-Spec. Error : 0.385, s/b : 1.064
# Steps : 35950, Gen Loss Total : 38.077, Mel-Spec. Error : 0.401, s/b : 1.072
# Steps : 36000, Gen Loss Total : 37.072, Mel-Spec. Error : 0.403, s/b : 1.059
# Saving checkpoint to cp_RPGAN_R1R2_lambda(0.0005)_G0D3/g_00036000
# Complete.
# Saving checkpoint to cp_RPGAN_R1R2_lambda(0.0005)_G0D3/do_00036000
# Complete.
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4142
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3806
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4965
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6504
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3308
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3737
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2987
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1952
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5235
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1532
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.068
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1932
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3735
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0076
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4038
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3474
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6396
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3156
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4312
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1455
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0975
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1847
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4398
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5448
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4688
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.15
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3179
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4303
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.7829
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3437
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.9269
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3172
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5205
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3423
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2033
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3806
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2662
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3994
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2911
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4494
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.745
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0761
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.283
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2538
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3235
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4234
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3382
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2459
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2946
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1862
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3077
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0544
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3087
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2522
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2923
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1674
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6239
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2967
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5273
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1208
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.536
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5051
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4093
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3528
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5716
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5371
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0364
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4205
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1742
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0055
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1585
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3169
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3434
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4559
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1559
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.9209
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3362
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.8896
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0488
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.9526
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3494
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5709
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4276
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2235
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2804
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2552
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0277
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.406
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2479
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4136
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4539
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.221
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1002
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4892
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3569
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0948
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2768
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1927
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2962
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4717
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2403
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1967
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0613
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4574
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.249
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3757
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2776
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2185
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.9957
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2319
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4143
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4114
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3069
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3143
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2916
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6365
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3339
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.306
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.033
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4375
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0904
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1354
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.9464
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.241
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3445
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2877
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.412
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2833
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3568
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6182
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5964
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0945
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6181
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2827
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3437
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6055
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4074
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3879
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4464
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5307
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3868
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3676
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5332
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2495
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.078
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3974
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6746
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3129
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4049
# Steps : 36050, Gen Loss Total : 34.406, Mel-Spec. Error : 0.370, s/b : 1.062
# Steps : 36100, Gen Loss Total : 40.174, Mel-Spec. Error : 0.397, s/b : 1.070
# Steps : 36150, Gen Loss Total : 36.326, Mel-Spec. Error : 0.386, s/b : 1.059
# Steps : 36200, Gen Loss Total : 35.405, Mel-Spec. Error : 0.374, s/b : 1.074
# Time taken for epoch 43 is 1090 sec
#
# Epoch: 44
# Steps : 36250, Gen Loss Total : 40.176, Mel-Spec. Error : 0.427, s/b : 1.068
# Steps : 36300, Gen Loss Total : 38.781, Mel-Spec. Error : 0.400, s/b : 1.054
# Steps : 36350, Gen Loss Total : 34.850, Mel-Spec. Error : 0.379, s/b : 1.069
# Steps : 36400, Gen Loss Total : 34.401, Mel-Spec. Error : 0.377, s/b : 1.051
# Steps : 36450, Gen Loss Total : 37.008, Mel-Spec. Error : 0.395, s/b : 1.057
# Steps : 36500, Gen Loss Total : 37.475, Mel-Spec. Error : 0.380, s/b : 1.067
# Steps : 36550, Gen Loss Total : 41.147, Mel-Spec. Error : 0.401, s/b : 1.056
# Steps : 36600, Gen Loss Total : 37.387, Mel-Spec. Error : 0.401, s/b : 1.072
# Steps : 36650, Gen Loss Total : 40.566, Mel-Spec. Error : 0.416, s/b : 1.070
# Steps : 36700, Gen Loss Total : 39.438, Mel-Spec. Error : 0.407, s/b : 1.101
# Steps : 36750, Gen Loss Total : 40.404, Mel-Spec. Error : 0.396, s/b : 1.057
# Steps : 36800, Gen Loss Total : 37.010, Mel-Spec. Error : 0.391, s/b : 1.089
# Steps : 36850, Gen Loss Total : 34.893, Mel-Spec. Error : 0.384, s/b : 1.057
# Steps : 36900, Gen Loss Total : 37.118, Mel-Spec. Error : 0.416, s/b : 1.065
# Steps : 36950, Gen Loss Total : 35.253, Mel-Spec. Error : 0.396, s/b : 1.074
# Steps : 37000, Gen Loss Total : 44.413, Mel-Spec. Error : 0.415, s/b : 1.064
# Saving checkpoint to cp_RPGAN_R1R2_lambda(0.0005)_G0D3/g_00037000
# Complete.
# Saving checkpoint to cp_RPGAN_R1R2_lambda(0.0005)_G0D3/do_00037000
# Complete.
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3586
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3571
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5687
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6059
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3943
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.329
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3088
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.104
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5636
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1821
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0916
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1774
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.403
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1079
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2335
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3434
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6065
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2842
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3778
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0647
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.102
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2849
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3171
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4982
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4142
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1609
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2559
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2785
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1994
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3821
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1452
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2961
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4594
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3144
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3182
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2135
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2597
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3428
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3164
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2418
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5562
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.8536
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2445
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.9723
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5034
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3721
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6209
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2938
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5266
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3824
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0903
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3053
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1088
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3017
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2661
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2165
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1358
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.567
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2701
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6085
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2214
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5608
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4578
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.459
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3241
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.385
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3041
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0245
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4296
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2329
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0147
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0676
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.271
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2817
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3817
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1958
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.9474
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2061
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0055
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1288
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.9638
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3436
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6125
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4635
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2195
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0961
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3036
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0044
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4489
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2036
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3787
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3914
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1081
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0489
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6992
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3921
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2866
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3036
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2533
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1938
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4387
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.28
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3897
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.8819
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3431
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4269
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4277
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2745
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0783
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.9531
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2932
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5265
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4781
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1266
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.437
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2328
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6418
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.411
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1825
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0808
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5637
# ...
# Steps : 40750, Gen Loss Total : 40.959, Mel-Spec. Error : 0.392, s/b : 1.074
# Steps : 40800, Gen Loss Total : 38.982, Mel-Spec. Error : 0.407, s/b : 1.089
# Steps : 40850, Gen Loss Total : 36.336, Mel-Spec. Error : 0.395, s/b : 1.072
# Steps : 40900, Gen Loss Total : 38.952, Mel-Spec. Error : 0.388, s/b : 1.067
# Steps : 40950, Gen Loss Total : 38.137, Mel-Spec. Error : 0.405, s/b : 1.067
# Steps : 41000, Gen Loss Total : 35.986, Mel-Spec. Error : 0.380, s/b : 1.064
# Saving checkpoint to cp_RPGAN_R1R2_lambda(0.0005)_G0D3/g_00041000
# Complete.
# Saving checkpoint to cp_RPGAN_R1R2_lambda(0.0005)_G0D3/do_00041000
# Complete.
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.388
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4457
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5772
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6873
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3799
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3866
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3438
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3015
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4586
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1816
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1288
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1987
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3905
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1794
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2558
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4238
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5829
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2916
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3683
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3016
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1412
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2233
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3843
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5471
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5209
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2919
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3825
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4173
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6008
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4179
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2494
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4286
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5953
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3925
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3722
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2648
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3855
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3344
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4055
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3407
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5616
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 2.9133
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1361
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.192
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2804
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2551
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5055
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3258
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.326
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.299
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.143
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2671
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0683
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.319
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.277
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3464
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0638
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6073
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2794
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6908
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.109
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5282
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4359
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5119
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3805
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5823
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3735
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1046
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4887
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2763
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0532
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1429
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2347
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3771
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4439
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2965
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1049
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2088
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1361
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1244
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0429
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3288
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.7229
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5557
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3987
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1995
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2873
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.138
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5435
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2818
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.468
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4102
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.343
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1084
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5797
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3768
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3956
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1597
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2851
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2787
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5384
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3209
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3832
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0538
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4046
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2577
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4316
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3112
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0602
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1139
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.236
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.387
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4755
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3078
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3264
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3936
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5641
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4598
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3764
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1641
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5916
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2129
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1953
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.0632
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1886
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3309
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1886
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.412
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2849
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3368
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.6058
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5608
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4832
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5647
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3816
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5203
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5025
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4243
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3776
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4249
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4925
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3401
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5163
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5577
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.2919
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.1298
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4296
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.5188
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.3349
# SCOREQ | No-Reference Mode | Domain natural | temp_test.wav: 3.4437
# Steps : 41050, Gen Loss Total : 40.905, Mel-Spec. Error : 0.424, s/b : 1.059
# Time taken for epoch 49 is 1098 sec
#
# Epoch: 50
# Steps : 41100, Gen Loss Total : 39.497, Mel-Spec. Error : 0.400, s/b : 1.065
# Steps : 41150, Gen Loss Total : 42.710, Mel-Spec. Error : 0.411, s/b : 1.064
# Steps : 41200, Gen Loss Total : 37.562, Mel-Spec. Error : 0.377, s/b : 1.061
# Steps : 41250, Gen Loss Total : 43.678, Mel-Spec. Error : 0.420, s/b : 1.063
# Steps : 41300, Gen Loss Total : 39.832, Mel-Spec. Error : 0.415, s/b : 1.087
# Steps : 41350, Gen Loss Total : 38.537, Mel-Spec. Error : 0.404, s/b : 1.081
# Steps : 41400, Gen Loss Total : 39.112, Mel-Spec. Error : 0.413, s/b : 1.063
# Steps : 41450, Gen Loss Total : 38.648, Mel-Spec. Error : 0.384, s/b : 1.077
# Steps : 41500, Gen Loss Total : 37.637, Mel-Spec. Error : 0.409, s/b : 1.068
# Steps : 41550, Gen Loss Total : 35.873, Mel-Spec. Error : 0.379, s/b : 1.067
# Steps : 41600, Gen Loss Total : 34.994, Mel-Spec. Error : 0.381, s/b : 1.058
# Steps : 41650, Gen Loss Total : 35.638, Mel-Spec. Error : 0.371, s/b : 1.066
# Steps : 41700, Gen Loss Total : 42.739, Mel-Spec. Error : 0.410, s/b : 1.067
# Steps : 41750, Gen Loss Total : 37.335, Mel-Spec. Error : 0.403, s/b : 1.057
# Steps : 41800, Gen Loss Total : 38.400, Mel-Spec. Error : 0.392, s/b : 1.059
# Steps : 41850, Gen Loss Total : 41.137, Mel-Spec. Error : 0.408, s/b : 1.059
# Time taken for epoch 50 is 863 sec
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/loss_disc_all</td><td>▂▄▃▂▂▄▃▄▃▃▃▃▃▃▃▁▁▂▃▂▄▃▂▄▃▃▂▁▂▆▂▄▄▃█▂▂▄▁▃</td></tr><tr><td>train/loss_disc_f</td><td>▆▇▆▅▄▄▄▄▄▁▇▃▂▄▄▅▅▅▃▄▅▅▆▇▃▅▅▆▃▄▇▅▄▅▆▆▆▆▄█</td></tr><tr><td>train/loss_disc_s </td><td>▆▃▆▃▂▄▄▁▄▆▄▄▂▅▃▅▅▄▅▆█▅▅▄▄▅▅▃▅▃▃▃▅▃▄▅▂▆▅▆</td></tr><tr><td>train/loss_fm_f</td><td>▅▂▄▃█▅▅▄▇█▅▁▆▄█▆▅▃▆▅▆▇▄▆▃▅▅▄▄▅▃▄▃▆▅▄▅█▅▆</td></tr><tr><td>train/loss_fm_s</td><td>▂▄█▆▃▂▅▃▇▅▅▃▆▂▃▂▁▂▃▂█▃▃▃▄▄▁▃▄▃▂▅▅▄▆▄▃▄▄▃</td></tr><tr><td>train/loss_gen_all</td><td>▂▃▃▂▃▂▅▂▅▅▃▃▅▄▅▄▃▃▆▄▄▃▃▄▃▁▃█▄▃▂▅▄▇▆▃▄▅▄▄</td></tr><tr><td>train/loss_gen_f</td><td>▅█▄▅▁▃▆▂█▃▆▁▇▇▄▄▁▄▁▄▄▄▅▄▃▅▅▆▂▅▇▅▂▇▅▄▃▃▄▃</td></tr><tr><td>train/loss_gen_s</td><td>▃▁▄▃▂▃█▃▂▃▅▃▃▃▂▂▂▂▄▃▂▃▂▂▁▄▂▃▂▃▄▂▅▂▅▅▄▅█▂</td></tr><tr><td>train/loss_mel</td><td>▆▅▅▇▆▅▂▇▃▂▄▄▆▄▇▆▅▅▃▄▄▃▅▅▅▄▄▄▅▇▁▃▇▃▇▅▄▆█▆</td></tr><tr><td>train/r1_penalty_mpd</td><td>▃▄▆█▇▇▅▅▇▄▅▅▂▄▂▃▇▃▅▅▄▅▅▂▄▃▅▄▂▁▂▂▄▄▄▆▄▂▆▂</td></tr><tr><td>train/r1_penalty_msd</td><td>▁▂▁▁▁▁▁▁▁▃▁▁▂▁▃▁█▁▂▁▁▁▁▁▁▁▂▃▁▁▁▁▁▂▃▂▁▁▁▁</td></tr><tr><td>train/r2_penalty_mpd</td><td>█▃▆▅▇▅▄▅▄▅▃▆▅▁▅▃▃▅▄▃▃▂▃▄█▅▄▅▅▃▃▃▅▁▄▆▁▃▄▂</td></tr><tr><td>train/r2_penalty_msd</td><td>▁▁▁▁▂▁▁▂▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation/val_err_f0rmse</td><td>▅▆▁▅█▅▄▇</td></tr><tr><td>validation/val_err_l1</td><td>▁█▆▅▁▅█▁</td></tr><tr><td>validation/val_err_lsd</td><td>▁▆▄▃▂▅█▁</td></tr><tr><td>validation/val_err_lsd_hf</td><td>▃█▁▅▂▃▃▂</td></tr><tr><td>validation/val_err_mos</td><td>▇▁▅▅█▇▅▇</td></tr><tr><td>validation/val_err_rmse</td><td>▁▆▅▃▁▄█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/loss_disc_all</td><td>19.85411</td></tr><tr><td>train/loss_disc_f</td><td>5.54501</td></tr><tr><td>train/loss_disc_s </td><td>3.30074</td></tr><tr><td>train/loss_fm_f</td><td>1.07852</td></tr><tr><td>train/loss_fm_s</td><td>9.7923</td></tr><tr><td>train/loss_gen_all</td><td>42.3504</td></tr><tr><td>train/loss_gen_f</td><td>5.54536</td></tr><tr><td>train/loss_gen_s</td><td>6.31418</td></tr><tr><td>train/loss_mel</td><td>19.62004</td></tr><tr><td>train/r1_penalty_mpd</td><td>4e-05</td></tr><tr><td>train/r1_penalty_msd</td><td>5.28706</td></tr><tr><td>train/r2_penalty_mpd</td><td>5e-05</td></tr><tr><td>train/r2_penalty_msd</td><td>5.72121</td></tr><tr><td>validation/val_err_f0rmse</td><td>82.40202</td></tr><tr><td>validation/val_err_l1</td><td>0.37752</td></tr><tr><td>validation/val_err_lsd</td><td>0.16199</td></tr><tr><td>validation/val_err_lsd_hf</td><td>0.08829</td></tr><tr><td>validation/val_err_mos</td><td>3.3461</td></tr><tr><td>validation/val_err_rmse</td><td>0.52969</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">RPGAN_R1R2_lambda(0.0005)_G0D3</strong> at: <a href='https://wandb.ai/spdlxmvmfl-korea-university/RPGAN_R1R2_LAMBDA_G0D3/runs/rpgan_r1r2_lambda0.0005_G0D3' target="_blank">https://wandb.ai/spdlxmvmfl-korea-university/RPGAN_R1R2_LAMBDA_G0D3/runs/rpgan_r1r2_lambda0.0005_G0D3</a><br> View project at: <a href='https://wandb.ai/spdlxmvmfl-korea-university/RPGAN_R1R2_LAMBDA_G0D3' target="_blank">https://wandb.ai/spdlxmvmfl-korea-university/RPGAN_R1R2_LAMBDA_G0D3</a><br>Synced 5 W&B file(s), 120 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250307_084242-rpgan_r1r2_lambda0.0005_G0D3/logs</code>

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-4f76a9dad686> in <cell line: 0>()
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %% [markdown]
# # hifi-inference

# %%
class Args:
        group_name = None
        input_wavs_dir = 'test_files'
        output_dir = 'generated_files'
        checkpoint_file = 'cp_in_hifigan/generator_v1.pth'

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import glob
import os
import argparse
import json
import torch
from scipy.io.wavfile import write
# from env import AttrDict
# from meldataset import mel_spectrogram, MAX_WAV_VALUE, load_wav
# from models import Generator

h = None
device = None


def load_checkpoint(filepath, device):
    assert os.path.isfile(filepath)
    print("Loading '{}'".format(filepath))
    checkpoint_dict = torch.load(filepath, map_location=device)
    print("Complete.")
    return checkpoint_dict


def get_mel(x):
    return mel_spectrogram(x, h.n_fft, h.num_mels, h.sampling_rate, h.hop_size, h.win_size, h.fmin, h.fmax)


def scan_checkpoint(cp_dir, prefix):
    pattern = os.path.join(cp_dir, prefix + '*')
    cp_list = glob.glob(pattern)
    if len(cp_list) == 0:
        return ''
    return sorted(cp_list)[-1]


def inference(a):
    generator = Generator(h).to(device)

    state_dict_g = load_checkpoint(a.checkpoint_file, device)
    generator.load_state_dict(state_dict_g['generator'])

    filelist = os.listdir(a.input_wavs_dir)

    os.makedirs(a.output_dir, exist_ok=True)

    generator.eval()
    generator.remove_weight_norm()
    with torch.no_grad():
        for i, filname in enumerate(filelist):
            wav, sr = load_wav(os.path.join(a.input_wavs_dir, filname))
            wav = wav / MAX_WAV_VALUE
            wav = torch.FloatTensor(wav).to(device)
            x = get_mel(wav.unsqueeze(0))
            y_g_hat = generator(x)
            audio = y_g_hat.squeeze()
            audio = audio * MAX_WAV_VALUE
            audio = audio.cpu().numpy().astype('int16')

            output_file = os.path.join(a.output_dir, os.path.splitext(filname)[0] + '_generated.wav')
            write(output_file, h.sampling_rate, audio)
            print(output_file)


def main():
    print('Initializing Inference Process..')

    # parser = argparse.ArgumentParser()
    # parser.add_argument('--input_wavs_dir', default='test_files')
    # parser.add_argument('--output_dir', default='generated_files')
    # parser.add_argument('--checkpoint_file', required=True)
    # a = parser.parse_args()

    config_file = os.path.join(os.path.split(a.checkpoint_file)[0], 'config.json')
    with open(config_file) as f:
        data = f.read()

    global h
    json_config = json.loads(data)
    h = AttrDict(json_config)

    torch.manual_seed(h.seed)
    global device
    if torch.cuda.is_available():
        torch.cuda.manual_seed(h.seed)
        device = torch.device('cuda')
    else:
        device = torch.device('cpu')

    inference(a)


if __name__ == '__main__':
    a = Args()
    main()

# %%
#inference e2e
from __future__ import absolute_import, division, print_function, unicode_literals

import glob
import os
import numpy as np
import argparse
import json
import torch
from scipy.io.wavfile import write
# from env import AttrDict
# from meldataset import MAX_WAV_VALUE
# from models import Generator

h = None
device = None


def load_checkpoint(filepath, device):
    assert os.path.isfile(filepath)
    print("Loading '{}'".format(filepath))
    checkpoint_dict = torch.load(filepath, map_location=device)
    print("Complete.")
    return checkpoint_dict


def scan_checkpoint(cp_dir, prefix):
    pattern = os.path.join(cp_dir, prefix + '*')
    cp_list = glob.glob(pattern)
    if len(cp_list) == 0:
        return ''
    return sorted(cp_list)[-1]


def inference(a):
    generator = Generator(h).to(device)

    state_dict_g = load_checkpoint(a.checkpoint_file, device)
    generator.load_state_dict(state_dict_g['generator'])

    filelist = os.listdir(a.input_mels_dir)

    os.makedirs(a.output_dir, exist_ok=True)

    generator.eval()
    generator.remove_weight_norm()
    with torch.no_grad():
        for i, filname in enumerate(filelist):
            x = np.load(os.path.join(a.input_mels_dir, filname))
            x = torch.FloatTensor(x).to(device)
            y_g_hat = generator(x)
            audio = y_g_hat.squeeze()
            audio = audio * MAX_WAV_VALUE
            audio = audio.cpu().numpy().astype('int16')

            output_file = os.path.join(a.output_dir, os.path.splitext(filname)[0] + '_generated_e2e.wav')
            write(output_file, h.sampling_rate, audio)
            print(output_file)


def main():
    print('Initializing Inference Process..')

    parser = argparse.ArgumentParser()
    parser.add_argument('--input_mels_dir', default='test_mel_files')
    parser.add_argument('--output_dir', default='generated_files_from_mel')
    parser.add_argument('--checkpoint_file', required=True)
    a = parser.parse_args()

    config_file = os.path.join(os.path.split(a.checkpoint_file)[0], 'config.json')
    with open(config_file) as f:
        data = f.read()

    global h
    json_config = json.loads(data)
    h = AttrDict(json_config)

    torch.manual_seed(h.seed)
    global device
    if torch.cuda.is_available():
        torch.cuda.manual_seed(h.seed)
        device = torch.device('cuda')
    else:
        device = torch.device('cpu')

    inference(a)


if __name__ == '__main__':
    main()
